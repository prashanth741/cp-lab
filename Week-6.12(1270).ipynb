# %% [markdown]
# <a href="https://colab.research.google.com/github/prashanth741/cp-lab/blob/main/Week-6.12(1270).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Bellman-Ford Algorithm

# Step 1: Read N and M
first_line = input().strip()
while first_line == "":
    first_line = input().strip()

N, M = map(int, first_line.split())

# Step 2: Read edges
edges = []
for _ in range(M):
    line = input().strip()
    while line == "":
        line = input().strip()
    u, v, w = map(int, line.split())
    edges.append((u, v, w))

# Step 3: Read Source
source_line = input().strip()
while source_line == "":
    source_line = input().strip()

S = int(source_line)

# Step 4: Bellman-Ford
INF = float('inf')
distance = [INF] * N
distance[S] = 0

# Relax edges N-1 times
for _ in range(N - 1):
    for u, v, w in edges:
        if distance[u] != INF and distance[u] + w < distance[v]:
            distance[v] = distance[u] + w

# Step 5: Check negative cycle
for u, v, w in edges:
    if distance[u] != INF and distance[u] + w < distance[v]:
        print("NEGATIVE CYCLE")
        break
else:
    for d in distance:
        print(d if d != INF else "INF")
# Out:
# 4 5
# 0 1 4
# 1 2 -6
# 2 3 3
# 3 1 2
# 0 3 10
# 0
# NEGATIVE CYCLE
