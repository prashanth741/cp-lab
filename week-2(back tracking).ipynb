# %% [markdown]
# <a href="https://colab.research.google.com/github/prashanth741/cp-lab/blob/main/week-2(back%20tracking).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def subset_sum(arr, n, target):


    if target == 0:
        return True


    if n == 0 or target < 0:
        return False


    include = subset_sum(arr, n - 1, target - arr[n - 1])


    exclude = subset_sum(arr, n - 1, target)

    return include or exclude

n = int(input())
arr = list(map(int, input().split()))
target = int(input())


result = subset_sum(arr, n, target)


print(result)
# Out:
# 5
# 3 34 4 12 5
# 9
# True
