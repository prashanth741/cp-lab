# %% [markdown]
# <a href="https://colab.research.google.com/github/prashanth741/cp-lab/blob/main/Week-7.13(1270).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

# Read number of nodes and edges
N, M = map(int, input().split())

# Create adjacency list
graph = [[] for _ in range(N)]

# Read edges
for _ in range(M):
    u, v, w = map(int, input().split())
    graph[u].append((w, v))
    graph[v].append((w, u))   # Undirected graph

# Prim's Algorithm
visited = [False] * N
min_heap = [(0, 0)]   # (cost, node)
total_cost = 0

while min_heap:
    cost, node = heapq.heappop(min_heap)

    if visited[node]:
        continue

    visited[node] = True
    total_cost += cost

    for edge_cost, neighbor in graph[node]:
        if not visited[neighbor]:
            heapq.heappush(min_heap, (edge_cost, neighbor))

print("Minimum Cost of MST =", total_cost)
# Out:
# 5 7
# 0 1 2
# 0 3 6
# 1 2 3
# 1 3 8
# 1 4 5
# 2 4 7
# 3 4 9
# Minimum Cost of MST = 16
