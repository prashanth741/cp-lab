# %% [markdown]
# <a href="https://colab.research.google.com/github/prashanth741/cp-lab/blob/main/Week-5.9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class DisjointSetUnion:
    def __init__(self, n):
        self.parent = [i for i in range(n)]
        self.rank = [0] * n

    def find(self, u):
        if self.parent[u] != u:
            self.parent[u] = self.find(self.parent[u])
        return self.parent[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)

        if root_u != root_v:
            if self.rank[root_u] < self.rank[root_v]:
                self.parent[root_u] = root_v
            elif self.rank[root_u] > self.rank[root_v]:
                self.parent[root_v] = root_u
            else:
                self.parent[root_v] = root_u
                self.rank[root_u] += 1

    def connected(self, u, v):
        return self.find(u) == self.find(v)


n = int(input("Enter number of servers: "))
dsu = DisjointSetUnion(n)

m = int(input("Enter number of connections: "))

print("Enter connections (u v):")
for _ in range(m):
    u, v = map(int, input().split())
    dsu.union(u, v)

q = int(input("Enter number of connectivity queries: "))

print("Enter queries (u v):")
result = []
for _ in range(q):
    u, v = map(int, input().split())
    if dsu.connected(u, v):
        result.append("YES")
    else:
        result.append("NO")
for res in result:
    print(res)
# Out:
# Enter number of servers: 6
# Enter number of connections: 4
# Enter connections (u v):
# 0 1
# 1 2
# 2 3
# 3 4
# Enter number of connectivity queries: 3
# Enter queries (u v):
# 0 2
# 0 5
# 3 5
# YES
# NO
# NO
