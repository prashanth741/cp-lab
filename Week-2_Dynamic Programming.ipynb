# %% [markdown]
# <a href="https://colab.research.google.com/github/prashanth741/cp-lab/blob/main/Week-2_Dynamic%20Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#

def fibonacci(n, memo):
    # Base cases
    if n == 0:
        return 0
    if n == 1:
        return 1

    if n in memo:
        return memo[n]

    memo[n] = fibonacci(n - 1, memo) + fibonacci(n - 2, memo)
    return memo[n]

n = int(input())

memo = {}

result = fibonacci(n, memo)
print(result)
# Out:
# 10
# 55
